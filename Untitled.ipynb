# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.examples.tutorials.mnist import input_data
from model import model
from sklearn import decomposition
from CW_attack import l2_attack

def weight_variable(shape):
    initial = tf.truncated_normal(shape, stddev=0.1)
    return tf.Variable(initial)

def bias_variable(shape):
    initial = tf.constant(0.1, shape = shape)
    return tf.Variable(initial)

def conv2d(x, W):
    return tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding = 'SAME')

def max_pool_2x2(x):
    return tf.nn.max_pool(x, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding = 'SAME')

def plot_digits(vecs, nrows, ncols):
    data = np.reshape(vecs, [nrows, ncols, -1])
    f, axs = plt.subplots(nrows, ncols)
    for i in range(nrows):
        for j in range(ncols):
            axs[i][j].imshow(np.reshape(data[i][j], [28, 28], order = 'C'))
            axs[i][j].axis('off')
    plt.show()

mnist = input_data.read_data_sets("MNIST_data/", one_hot = True)

x = tf.placeholder(tf.float32, [None, 784])
y_ = tf.placeholder(tf.float32, [None, 10])
W_conv1 = weight_variable([5, 5, 1, 32])
b_conv1 = bias_variable([32])

x_image = tf.reshape(x, [-1, 28, 28, 1])
h_conv1 = tf.nn.relu(conv2d(x_image, W_conv1) + b_conv1)
h_pool1 = max_pool_2x2(h_conv1)

W_conv2 = weight_variable([5, 5, 32, 64])
b_conv2 = bias_variable([64])
h_conv2 = tf.nn.relu(conv2d(h_pool1, W_conv2) + b_conv2)
h_pool2 = max_pool_2x2(h_conv2)

W_fc1 = weight_variable([7*7*64, 1024])
b_fc1 = bias_variable([1024])
h_pool2_flat = tf.reshape(h_pool2, [-1, 7*7*64])
h_fc1 = tf.nn.relu(tf.matmul(h_pool2_flat, W_fc1) + b_fc1)

keep_prob = tf.placeholder(tf.float32)
h_fc1_drop = tf.nn.dropout(h_fc1, keep_prob)

W_fc2 = weight_variable([1024, 10])
b_fc2 = bias_variable([10])
y_conv = tf.matmul(h_fc1_drop, W_fc2) + b_fc2

cross_entropy = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels = y_, logits = y_conv))
train_step = tf.train.AdamOptimizer(1e-4).minimize(cross_entropy)
correct_prediction = tf.equal(tf.argmax(y_conv, 1), tf.argmax(y_, 1))
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
# Out:
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz

# %%
train_im = mnist.train.images
train_pca = decomposition.PCA(100).fit(train_im)
W = train_pca.components_

sess = tf.Session()
sess.run(tf.global_variables_initializer())

for i in range(20000):
    batch = mnist.train.next_batch(50)
    trans_pic = batch[0] @ W.T @ W
    if i % 100 == 0:
        train_accuracy = accuracy.eval(feed_dict = {x: trans_pic, y_: batch[1], keep_prob: 0.8}, session = sess)
#         saver.save(sess, "easy_conv/")
        print("step %d, training accuracy %g" % (i, train_accuracy))
    train_step.run(feed_dict = {x: trans_pic, y_: batch[1], keep_prob: 0.5}, session = sess)
# saver.save(sess, "easy_conv/")
# Out:
# step 0, training accuracy 0.16
# step 100, training accuracy 0.94
# step 200, training accuracy 0.82
# step 300, training accuracy 0.8
# step 400, training accuracy 0.98
# step 500, training accuracy 0.94
# step 600, training accuracy 0.92
# step 700, training accuracy 0.94
# step 800, training accuracy 0.96
# step 900, training accuracy 0.96
# step 1000, training accuracy 1
# step 1100, training accuracy 0.98
# step 1200, training accuracy 0.98
# step 1300, training accuracy 0.96
# step 1400, training accuracy 0.98
# step 1500, training accuracy 0.94
# step 1600, training accuracy 1
# step 1700, training accuracy 0.98
# step 1800, training accuracy 1
# step 1900, training accuracy 0.94
# step 2000, training accuracy 1
# step 2100, training accuracy 0.96
# step 2200, training accuracy 0.94
# step 2300, training accuracy 0.96
# step 2400, training accuracy 0.98
# step 2500, training accuracy 0.98
# step 2600, training accuracy 1
# step 2700, training accuracy 1
# step 2800, training accuracy 0.96
# step 2900, training accuracy 1
# step 3000, training accuracy 0.96
# step 3100, training accuracy 0.98
# step 3200, training accuracy 0.96
# step 3300, training accuracy 0.96
# step 3400, training accuracy 1
# step 3500, training accuracy 0.98
# step 3600, training accuracy 0.98
# step 3700, training accuracy 0.98
# step 3800, training accuracy 0.98
# step 3900, training accuracy 1
# step 4000, training accuracy 0.98
# step 4100, training accuracy 1
# step 4200, training accuracy 0.98
# step 4300, training accuracy 0.94
# step 4400, training accuracy 1
# step 4500, training accuracy 1
# step 4600, training accuracy 0.98
# step 4700, training accuracy 1
# step 4800, training accuracy 0.98
# step 4900, training accuracy 1
# step 5000, training accuracy 1
# step 5100, training accuracy 1
# step 5200, training accuracy 1
# step 5300, training accuracy 1
# step 5400, training accuracy 1
# step 5500, training accuracy 1
# step 5600, training accuracy 1
# step 5700, training accuracy 0.98
# step 5800, training accuracy 1
# step 5900, training accuracy 0.98
# step 6000, training accuracy 1
# step 6100, training accuracy 0.96
# step 6200, training accuracy 1
# step 6300, training accuracy 1
# step 6400, training accuracy 1
# step 6500, training accuracy 1
# step 6600, training accuracy 1
# step 6700, training accuracy 1
# step 6800, training accuracy 1
# step 6900, training accuracy 0.98
# step 7000, training accuracy 1
# step 7100, training accuracy 0.98
# step 7200, training accuracy 1
# step 7300, training accuracy 1
# step 7400, training accuracy 0.98
# step 7500, training accuracy 0.98
# step 7600, training accuracy 0.98
# step 7700, training accuracy 0.98
# step 7800, training accuracy 1
# step 7900, training accuracy 1
# step 8000, training accuracy 1
# step 8100, training accuracy 0.98
# step 8200, training accuracy 0.96
# step 8300, training accuracy 0.92
# step 8400, training accuracy 1
# step 8500, training accuracy 1
# step 8600, training accuracy 1
# step 8700, training accuracy 1
# step 8800, training accuracy 1
# step 8900, training accuracy 1
# step 9000, training accuracy 1
# step 9100, training accuracy 1
# step 9200, training accuracy 1
# step 9300, training accuracy 1
# step 9400, training accuracy 1
# step 9500, training accuracy 1
# step 9600, training accuracy 1
# step 9700, training accuracy 1
# step 9800, training accuracy 1
# step 9900, training accuracy 0.98
# step 10000, training accuracy 0.98
# step 10100, training accuracy 1
# step 10200, training accuracy 1
# step 10300, training accuracy 1
# step 10400, training accuracy 1
# step 10500, training accuracy 1
# step 10600, training accuracy 0.98
# step 10700, training accuracy 1
# step 10800, training accuracy 1
# step 10900, training accuracy 1
# step 11000, training accuracy 1
# step 11100, training accuracy 0.98
# step 11200, training accuracy 1
# step 11300, training accuracy 1
# step 11400, training accuracy 1
# step 11500, training accuracy 0.98
# step 11600, training accuracy 1
# step 11700, training accuracy 1
# step 11800, training accuracy 0.98
# step 11900, training accuracy 1
# step 12000, training accuracy 1
# step 12100, training accuracy 0.98
# step 12200, training accuracy 1
# step 12300, training accuracy 1
# step 12400, training accuracy 1
# step 12500, training accuracy 1
# step 12600, training accuracy 0.98
# step 12700, training accuracy 1
# step 12800, training accuracy 1
# step 12900, training accuracy 1
# step 13000, training accuracy 1
# step 13100, training accuracy 1
# step 13200, training accuracy 1
# step 13300, training accuracy 1
# step 13400, training accuracy 0.98
# step 13500, training accuracy 1
# step 13600, training accuracy 1
# step 13700, training accuracy 1
# step 13800, training accuracy 1
# step 13900, training accuracy 1
# step 14000, training accuracy 1
# step 14100, training accuracy 1
# step 14200, training accuracy 0.98
# step 14300, training accuracy 1
# step 14400, training accuracy 1
# step 14500, training accuracy 1
# step 14600, training accuracy 1
# step 14700, training accuracy 1
# step 14800, training accuracy 1
# step 14900, training accuracy 1
# step 15000, training accuracy 1
# step 15100, training accuracy 1
# step 15200, training accuracy 1
# step 15300, training accuracy 1
# step 15400, training accuracy 1
# step 15500, training accuracy 1
# step 15600, training accuracy 1
# step 15700, training accuracy 1
# step 15800, training accuracy 1
# step 15900, training accuracy 1
# step 16000, training accuracy 1
# step 16100, training accuracy 1
# step 16200, training accuracy 1
# step 16300, training accuracy 1
# step 16400, training accuracy 1
# step 16500, training accuracy 1
# step 16600, training accuracy 0.98
# step 16700, training accuracy 1
# step 16800, training accuracy 1
# step 16900, training accuracy 1
# step 17000, training accuracy 1
# step 17100, training accuracy 1
# step 17200, training accuracy 1
# step 17300, training accuracy 1
# step 17400, training accuracy 1
# step 17500, training accuracy 1
# step 17600, training accuracy 1
# step 17700, training accuracy 1
# step 17800, training accuracy 1
# step 17900, training accuracy 1
# step 18000, training accuracy 1
# step 18100, training accuracy 1
# step 18200, training accuracy 1
# step 18300, training accuracy 1
# step 18400, training accuracy 1
# step 18500, training accuracy 1
# step 18600, training accuracy 0.98
# step 18700, training accuracy 1
# step 18800, training accuracy 1
# step 18900, training accuracy 1
# step 19000, training accuracy 1
# step 19100, training accuracy 1
# step 19200, training accuracy 1
# step 19300, training accuracy 1
# step 19400, training accuracy 1
# step 19500, training accuracy 1
# step 19600, training accuracy 1
# step 19700, training accuracy 1
# step 19800, training accuracy 1
# step 19900, training accuracy 1

# %%
simple_conv = model(y_conv, cross_entropy, train_step, [x, keep_prob])
test_images = mnist.test.images[0:100]
fd = [test_images, 1.0]
adv_img = l2_attack(simple_conv, sess, fd, 0.01, 3e-3, test_images, 3, 10)

adv_img_deno = adv_img @ W.T @ W
print("test accuracy %g" % accuracy.eval(feed_dict = {x: adv_img_deno, y_: mnist.test.labels[0:100], keep_prob: 1.0}, session = sess))
plot_digits(adv_img, 10, 10)
plot_digits(adv_img_deno, 10, 10)
# Out:
# This is 0th iteration. The loss is 6747.16015625.
# This is 1th iteration. The loss is 6726.4921875.
# This is 2th iteration. The loss is 6705.86181640625.
# This is 3th iteration. The loss is 6685.26953125.
# This is 4th iteration. The loss is 6664.71533203125.
# This is 5th iteration. The loss is 6644.19970703125.
# This is 6th iteration. The loss is 6623.72412109375.
# This is 7th iteration. The loss is 6603.2890625.
# This is 8th iteration. The loss is 6582.8955078125.
# This is 9th iteration. The loss is 6562.54345703125.
# This is 10th iteration. The loss is 6542.234375.
# This is 11th iteration. The loss is 6521.96728515625.
# This is 12th iteration. The loss is 6501.74658203125.
# This is 13th iteration. The loss is 6481.5703125.
# This is 14th iteration. The loss is 6461.4404296875.
# This is 15th iteration. The loss is 6441.35693359375.
# This is 16th iteration. The loss is 6421.322265625.
# This is 17th iteration. The loss is 6401.3369140625.
# This is 18th iteration. The loss is 6381.39990234375.
# This is 19th iteration. The loss is 6361.51416015625.
# This is 20th iteration. The loss is 6341.6796875.
# This is 21th iteration. The loss is 6321.896484375.
# This is 22th iteration. The loss is 6302.16748046875.
# This is 23th iteration. The loss is 6282.48974609375.
# This is 24th iteration. The loss is 6262.86767578125.
# This is 25th iteration. The loss is 6243.29931640625.
# This is 26th iteration. The loss is 6223.787109375.
# This is 27th iteration. The loss is 6204.33056640625.
# This is 28th iteration. The loss is 6184.9306640625.
# This is 29th iteration. The loss is 6165.58837890625.
# This is 30th iteration. The loss is 6146.30322265625.
# This is 31th iteration. The loss is 6127.0771484375.
# This is 32th iteration. The loss is 6107.9091796875.
# This is 33th iteration. The loss is 6088.8017578125.
# This is 34th iteration. The loss is 6069.75390625.
# This is 35th iteration. The loss is 6050.76611328125.
# This is 36th iteration. The loss is 6031.83984375.
# This is 37th iteration. The loss is 6012.97412109375.
# This is 38th iteration. The loss is 5994.17138671875.
# This is 39th iteration. The loss is 5975.43017578125.
# This is 40th iteration. The loss is 5956.751953125.
# This is 41th iteration. The loss is 5938.13623046875.
# This is 42th iteration. The loss is 5919.58447265625.
# This is 43th iteration. The loss is 5901.09716796875.
# This is 44th iteration. The loss is 5882.6728515625.
# This is 45th iteration. The loss is 5864.31396484375.
# This is 46th iteration. The loss is 5846.01953125.
# This is 47th iteration. The loss is 5827.79052734375.
# This is 48th iteration. The loss is 5809.626953125.
# This is 49th iteration. The loss is 5791.52880859375.
# This is 50th iteration. The loss is 5773.49658203125.
# This is 51th iteration. The loss is 5755.53173828125.
# This is 52th iteration. The loss is 5737.63134765625.
# This is 53th iteration. The loss is 5719.7998046875.
# This is 54th iteration. The loss is 5702.03466796875.
# This is 55th iteration. The loss is 5684.33642578125.
# This is 56th iteration. The loss is 5666.705078125.
# This is 57th iteration. The loss is 5649.14208984375.
# This is 58th iteration. The loss is 5631.6474609375.
# This is 59th iteration. The loss is 5614.2197265625.
# This is 60th iteration. The loss is 5596.86083984375.
# This is 61th iteration. The loss is 5579.56982421875.
# This is 62th iteration. The loss is 5562.3466796875.
# This is 63th iteration. The loss is 5545.19287109375.
# This is 64th iteration. The loss is 5528.10791015625.
# This is 65th iteration. The loss is 5511.09228515625.
# This is 66th iteration. The loss is 5494.14453125.
# This is 67th iteration. The loss is 5477.2666015625.
# This is 68th iteration. The loss is 5460.4580078125.
# This is 69th iteration. The loss is 5443.71728515625.
# This is 70th iteration. The loss is 5427.046875.
# This is 71th iteration. The loss is 5410.4453125.
# This is 72th iteration. The loss is 5393.9140625.
# This is 73th iteration. The loss is 5377.45166015625.
# This is 74th iteration. The loss is 5361.05908203125.
# This is 75th iteration. The loss is 5344.73583984375.
# This is 76th iteration. The loss is 5328.48193359375.
# This is 77th iteration. The loss is 5312.29833984375.
# This is 78th iteration. The loss is 5296.1845703125.
# This is 79th iteration. The loss is 5280.14013671875.
# This is 80th iteration. The loss is 5264.166015625.
# This is 81th iteration. The loss is 5248.26123046875.
# This is 82th iteration. The loss is 5232.42578125.
# This is 83th iteration. The loss is 5216.66015625.
# This is 84th iteration. The loss is 5200.96435546875.
# This is 85th iteration. The loss is 5185.33837890625.
# This is 86th iteration. The loss is 5169.7822265625.
# This is 87th iteration. The loss is 5154.294921875.
# This is 88th iteration. The loss is 5138.8779296875.
# This is 89th iteration. The loss is 5123.5302734375.
# This is 90th iteration. The loss is 5108.251953125.
# This is 91th iteration. The loss is 5093.04296875.
# This is 92th iteration. The loss is 5077.90380859375.
# This is 93th iteration. The loss is 5062.83349609375.
# This is 94th iteration. The loss is 5047.8330078125.
# This is 95th iteration. The loss is 5032.900390625.
# This is 96th iteration. The loss is 5018.0380859375.
# This is 97th iteration. The loss is 5003.24462890625.
# This is 98th iteration. The loss is 4988.51953125.
# This is 99th iteration. The loss is 4973.86376953125.
# This is 100th iteration. The loss is 4959.27587890625.
# This is 101th iteration. The loss is 4944.75732421875.
# This is 102th iteration. The loss is 4930.3076171875.
# This is 103th iteration. The loss is 4915.92578125.
# This is 104th iteration. The loss is 4901.61181640625.
# This is 105th iteration. The loss is 4887.3671875.
# This is 106th iteration. The loss is 4873.18896484375.
# This is 107th iteration. The loss is 4859.0791015625.
# This is 108th iteration. The loss is 4845.03759765625.
# This is 109th iteration. The loss is 4831.06396484375.
# This is 110th iteration. The loss is 4817.1572265625.
# This is 111th iteration. The loss is 4803.31689453125.
# This is 112th iteration. The loss is 4789.544921875.
# This is 113th iteration. The loss is 4775.83984375.
# This is 114th iteration. The loss is 4762.201171875.
# This is 115th iteration. The loss is 4748.62890625.
# This is 116th iteration. The loss is 4735.12353515625.
# This is 117th iteration. The loss is 4721.68505859375.
# This is 118th iteration. The loss is 4708.3125.
# This is 119th iteration. The loss is 4695.005859375.
# This is 120th iteration. The loss is 4681.7646484375.
# This is 121th iteration. The loss is 4668.58935546875.
# This is 122th iteration. The loss is 4655.47998046875.
# This is 123th iteration. The loss is 4642.43505859375.
# This is 124th iteration. The loss is 4629.45556640625.
# This is 125th iteration. The loss is 4616.541015625.
# This is 126th iteration. The loss is 4603.69140625.
# This is 127th iteration. The loss is 4590.90673828125.
# This is 128th iteration. The loss is 4578.18505859375.
# This is 129th iteration. The loss is 4565.52880859375.
# This is 130th iteration. The loss is 4552.93603515625.
# This is 131th iteration. The loss is 4540.40673828125.
# This is 132th iteration. The loss is 4527.94091796875.
# This is 133th iteration. The loss is 4515.5380859375.
# This is 134th iteration. The loss is 4503.19970703125.
# This is 135th iteration. The loss is 4490.9228515625.
# This is 136th iteration. The loss is 4478.708984375.
# This is 137th iteration. The loss is 4466.55712890625.
# This is 138th iteration. The loss is 4454.46875.
# This is 139th iteration. The loss is 4442.44140625.
# This is 140th iteration. The loss is 4430.4755859375.
# This is 141th iteration. The loss is 4418.5712890625.
# This is 142th iteration. The loss is 4406.72900390625.
# This is 143th iteration. The loss is 4394.947265625.
# This is 144th iteration. The loss is 4383.2265625.
# This is 145th iteration. The loss is 4371.56689453125.
# This is 146th iteration. The loss is 4359.96728515625.
# This is 147th iteration. The loss is 4348.42724609375.
# This is 148th iteration. The loss is 4336.947265625.
# This is 149th iteration. The loss is 4325.52734375.
# This is 150th iteration. The loss is 4314.16650390625.
# This is 151th iteration. The loss is 4302.865234375.
# This is 152th iteration. The loss is 4291.62353515625.
# This is 153th iteration. The loss is 4280.439453125.
# This is 154th iteration. The loss is 4269.31396484375.
# This is 155th iteration. The loss is 4258.2470703125.
# This is 156th iteration. The loss is 4247.23828125.
# This is 157th iteration. The loss is 4236.2861328125.
# This is 158th iteration. The loss is 4225.39208984375.
# This is 159th iteration. The loss is 4214.5556640625.
# This is 160th iteration. The loss is 4203.775390625.
# This is 161th iteration. The loss is 4193.052734375.
# This is 162th iteration. The loss is 4182.3857421875.
# This is 163th iteration. The loss is 4171.775390625.
# This is 164th iteration. The loss is 4161.22119140625.
# This is 165th iteration. The loss is 4150.72265625.
# This is 166th iteration. The loss is 4140.279296875.
# This is 167th iteration. The loss is 4129.89111328125.
# This is 168th iteration. The loss is 4119.55810546875.
# This is 169th iteration. The loss is 4109.279296875.
# This is 170th iteration. The loss is 4099.0556640625.
# This is 171th iteration. The loss is 4088.885498046875.
# This is 172th iteration. The loss is 4078.77001953125.
# This is 173th iteration. The loss is 4068.7080078125.
# This is 174th iteration. The loss is 4058.698486328125.
# This is 175th iteration. The loss is 4048.7431640625.
# This is 176th iteration. The loss is 4038.84033203125.
# This is 177th iteration. The loss is 4028.99072265625.
# This is 178th iteration. The loss is 4019.19287109375.
# This is 179th iteration. The loss is 4009.447509765625.
# This is 180th iteration. The loss is 3999.753662109375.
# This is 181th iteration. The loss is 3990.112060546875.
# This is 182th iteration. The loss is 3980.52099609375.
# This is 183th iteration. The loss is 3970.981689453125.
# This is 184th iteration. The loss is 3961.4931640625.
# This is 185th iteration. The loss is 3952.05517578125.
# This is 186th iteration. The loss is 3942.667724609375.
# This is 187th iteration. The loss is 3933.329833984375.
# This is 188th iteration. The loss is 3924.042236328125.
# This is 189th iteration. The loss is 3914.803955078125.
# This is 190th iteration. The loss is 3905.614990234375.
# This is 191th iteration. The loss is 3896.47509765625.
# This is 192th iteration. The loss is 3887.38427734375.
# This is 193th iteration. The loss is 3878.34228515625.
# This is 194th iteration. The loss is 3869.34814453125.
# This is 195th iteration. The loss is 3860.40185546875.
# This is 196th iteration. The loss is 3851.504150390625.
# This is 197th iteration. The loss is 3842.6533203125.
# This is 198th iteration. The loss is 3833.849853515625.
# This is 199th iteration. The loss is 3825.09326171875.
# This is 200th iteration. The loss is 3816.3837890625.
# This is 201th iteration. The loss is 3807.72119140625.
# This is 202th iteration. The loss is 3799.103759765625.
# This is 203th iteration. The loss is 3790.533935546875.
# This is 204th iteration. The loss is 3782.0087890625.
# This is 205th iteration. The loss is 3773.529296875.
# This is 206th iteration. The loss is 3765.095947265625.
# This is 207th iteration. The loss is 3756.707275390625.
# This is 208th iteration. The loss is 3748.363525390625.
# This is 209th iteration. The loss is 3740.063720703125.
# This is 210th iteration. The loss is 3731.808837890625.
# This is 211th iteration. The loss is 3723.59716796875.
# This is 212th iteration. The loss is 3715.43017578125.
# This is 213th iteration. The loss is 3707.306396484375.
# This is 214th iteration. The loss is 3699.225830078125.
# This is 215th iteration. The loss is 3691.188720703125.
# This is 216th iteration. The loss is 3683.1943359375.
# This is 217th iteration. The loss is 3675.242919921875.
# This is 218th iteration. The loss is 3667.333740234375.
# This is 219th iteration. The loss is 3659.46728515625.
# This is 220th iteration. The loss is 3651.6416015625.
# This is 221th iteration. The loss is 3643.858642578125.
# This is 222th iteration. The loss is 3636.116455078125.
# This is 223th iteration. The loss is 3628.414794921875.
# This is 224th iteration. The loss is 3620.755126953125.
# This is 225th iteration. The loss is 3613.13671875.
# This is 226th iteration. The loss is 3605.5576171875.
# This is 227th iteration. The loss is 3598.01953125.
# This is 228th iteration. The loss is 3590.52099609375.
# This is 229th iteration. The loss is 3583.062255859375.
# This is 230th iteration. The loss is 3575.643798828125.
# This is 231th iteration. The loss is 3568.2646484375.
# This is 232th iteration. The loss is 3560.924072265625.
# This is 233th iteration. The loss is 3553.62255859375.
# This is 234th iteration. The loss is 3546.360107421875.
# This is 235th iteration. The loss is 3539.135986328125.
# This is 236th iteration. The loss is 3531.94921875.
# This is 237th iteration. The loss is 3524.801513671875.
# This is 238th iteration. The loss is 3517.691650390625.
# This is 239th iteration. The loss is 3510.61962890625.
# This is 240th iteration. The loss is 3503.583984375.
# This is 241th iteration. The loss is 3496.58544921875.
# This is 242th iteration. The loss is 3489.62451171875.
# This is 243th iteration. The loss is 3482.7001953125.
# This is 244th iteration. The loss is 3475.812744140625.
# This is 245th iteration. The loss is 3468.960693359375.
# This is 246th iteration. The loss is 3462.145263671875.
# This is 247th iteration. The loss is 3455.365478515625.
# This is 248th iteration. The loss is 3448.62158203125.
# This is 249th iteration. The loss is 3441.91259765625.
# This is 250th iteration. The loss is 3435.2392578125.
# This is 251th iteration. The loss is 3428.600830078125.
# This is 252th iteration. The loss is 3421.997314453125.
# This is 253th iteration. The loss is 3415.428466796875.
# This is 254th iteration. The loss is 3408.89404296875.
# This is 255th iteration. The loss is 3402.393310546875.
# This is 256th iteration. The loss is 3395.927001953125.
# This is 257th iteration. The loss is 3389.494873046875.
# This is 258th iteration. The loss is 3383.095947265625.
# This is 259th iteration. The loss is 3376.73046875.
# This is 260th iteration. The loss is 3370.39794921875.
# This is 261th iteration. The loss is 3364.098876953125.
# This is 262th iteration. The loss is 3357.83154296875.
# This is 263th iteration. The loss is 3351.59814453125.
# This is 264th iteration. The loss is 3345.396484375.
# This is 265th iteration. The loss is 3339.22705078125.
# This is 266th iteration. The loss is 3333.089599609375.
# This is 267th iteration. The loss is 3326.984375.
# This is 268th iteration. The loss is 3320.91015625.
# This is 269th iteration. The loss is 3314.867919921875.
# This is 270th iteration. The loss is 3308.857177734375.
# This is 271th iteration. The loss is 3302.876708984375.
# This is 272th iteration. The loss is 3296.92724609375.
# This is 273th iteration. The loss is 3291.009033203125.
# This is 274th iteration. The loss is 3285.12109375.
# This is 275th iteration. The loss is 3279.263427734375.
# This is 276th iteration. The loss is 3273.43603515625.
# This is 277th iteration. The loss is 3267.63818359375.
# This is 278th iteration. The loss is 3261.870849609375.
# This is 279th iteration. The loss is 3256.133056640625.
# This is 280th iteration. The loss is 3250.42431640625.
# This is 281th iteration. The loss is 3244.744873046875.
# This is 282th iteration. The loss is 3239.0947265625.
# This is 283th iteration. The loss is 3233.47314453125.
# This is 284th iteration. The loss is 3227.880615234375.
# This is 285th iteration. The loss is 3222.316162109375.
# This is 286th iteration. The loss is 3216.78076171875.
# This is 287th iteration. The loss is 3211.27294921875.
# This is 288th iteration. The loss is 3205.79345703125.
# This is 289th iteration. The loss is 3200.34228515625.
# This is 290th iteration. The loss is 3194.91796875.
# This is 291th iteration. The loss is 3189.521728515625.
# This is 292th iteration. The loss is 3184.1533203125.
# This is 293th iteration. The loss is 3178.811279296875.
# This is 294th iteration. The loss is 3173.496337890625.
# This is 295th iteration. The loss is 3168.208740234375.
# This is 296th iteration. The loss is 3162.94775390625.
# This is 297th iteration. The loss is 3157.71337890625.
# This is 298th iteration. The loss is 3152.505126953125.
# This is 299th iteration. The loss is 3147.3232421875.
# This is 300th iteration. The loss is 3142.16748046875.
# This is 301th iteration. The loss is 3137.0380859375.
# This is 302th iteration. The loss is 3131.933837890625.
# This is 303th iteration. The loss is 3126.854736328125.
# This is 304th iteration. The loss is 3121.802001953125.
# This is 305th iteration. The loss is 3116.7744140625.
# This is 306th iteration. The loss is 3111.771484375.
# This is 307th iteration. The loss is 3106.7939453125.
# This is 308th iteration. The loss is 3101.84130859375.
# This is 309th iteration. The loss is 3096.913330078125.
# This is 310th iteration. The loss is 3092.009765625.
# This is 311th iteration. The loss is 3087.13037109375.
# This is 312th iteration. The loss is 3082.275146484375.
# This is 313th iteration. The loss is 3077.44482421875.
# This is 314th iteration. The loss is 3072.637939453125.
# This is 315th iteration. The loss is 3067.855224609375.
# This is 316th iteration. The loss is 3063.095703125.
# This is 317th iteration. The loss is 3058.359619140625.
# This is 318th iteration. The loss is 3053.647705078125.
# This is 319th iteration. The loss is 3048.958251953125.
# This is 320th iteration. The loss is 3044.2919921875.
# This is 321th iteration. The loss is 3039.64892578125.
# This is 322th iteration. The loss is 3035.028564453125.
# This is 323th iteration. The loss is 3030.431396484375.
# This is 324th iteration. The loss is 3025.856201171875.
# This is 325th iteration. The loss is 3021.30322265625.
# This is 326th iteration. The loss is 3016.7734375.
# This is 327th iteration. The loss is 3012.265380859375.
# This is 328th iteration. The loss is 3007.77880859375.
# This is 329th iteration. The loss is 3003.314453125.
# This is 330th iteration. The loss is 2998.8720703125.
# This is 331th iteration. The loss is 2994.451416015625.
# This is 332th iteration. The loss is 2990.0517578125.
# This is 333th iteration. The loss is 2985.673583984375.
# This is 334th iteration. The loss is 2981.31640625.
# This is 335th iteration. The loss is 2976.98095703125.
# This is 336th iteration. The loss is 2972.666748046875.
# This is 337th iteration. The loss is 2968.37255859375.
# This is 338th iteration. The loss is 2964.099365234375.
# This is 339th iteration. The loss is 2959.8466796875.
# This is 340th iteration. The loss is 2955.614501953125.
# This is 341th iteration. The loss is 2951.4033203125.
# This is 342th iteration. The loss is 2947.211669921875.
# This is 343th iteration. The loss is 2943.040283203125.
# This is 344th iteration. The loss is 2938.88916015625.
# This is 345th iteration. The loss is 2934.757568359375.
# This is 346th iteration. The loss is 2930.64599609375.
# This is 347th iteration. The loss is 2926.553955078125.
# This is 348th iteration. The loss is 2922.4814453125.
# This is 349th iteration. The loss is 2918.427978515625.
# This is 350th iteration. The loss is 2914.39453125.
# This is 351th iteration. The loss is 2910.3798828125.
# This is 352th iteration. The loss is 2906.383544921875.
# This is 353th iteration. The loss is 2902.4072265625.
# This is 354th iteration. The loss is 2898.449951171875.
# This is 355th iteration. The loss is 2894.51025390625.
# This is 356th iteration. The loss is 2890.58984375.
# This is 357th iteration. The loss is 2886.687744140625.
# This is 358th iteration. The loss is 2882.804443359375.
# This is 359th iteration. The loss is 2878.93896484375.
# This is 360th iteration. The loss is 2875.092041015625.
# This is 361th iteration. The loss is 2871.2626953125.
# This is 362th iteration. The loss is 2867.451904296875.
# This is 363th iteration. The loss is 2863.658935546875.
# This is 364th iteration. The loss is 2859.88330078125.
# This is 365th iteration. The loss is 2856.12548828125.
# This is 366th iteration. The loss is 2852.385498046875.
# This is 367th iteration. The loss is 2848.66259765625.
# This is 368th iteration. The loss is 2844.95703125.
# This is 369th iteration. The loss is 2841.268310546875.
# This is 370th iteration. The loss is 2837.59765625.
# This is 371th iteration. The loss is 2833.943359375.
# This is 372th iteration. The loss is 2830.30615234375.
# This is 373th iteration. The loss is 2826.68603515625.
# This is 374th iteration. The loss is 2823.082275390625.
# This is 375th iteration. The loss is 2819.495361328125.
# This is 376th iteration. The loss is 2815.92529296875.
# This is 377th iteration. The loss is 2812.37109375.
# This is 378th iteration. The loss is 2808.833740234375.
# This is 379th iteration. The loss is 2805.31201171875.
# This is 380th iteration. The loss is 2801.806884765625.
# This is 381th iteration. The loss is 2798.3173828125.
# This is 382th iteration. The loss is 2794.84423828125.
# This is 383th iteration. The loss is 2791.386962890625.
# This is 384th iteration. The loss is 2787.9453125.
# This is 385th iteration. The loss is 2784.519775390625.
# This is 386th iteration. The loss is 2781.109375.
# This is 387th iteration. The loss is 2777.714599609375.
# This is 388th iteration. The loss is 2774.335693359375.
# This is 389th iteration. The loss is 2770.9716796875.
# This is 390th iteration. The loss is 2767.62255859375.
# This is 391th iteration. The loss is 2764.2890625.
# This is 392th iteration. The loss is 2760.970703125.
# This is 393th iteration. The loss is 2757.667236328125.
# This is 394th iteration. The loss is 2754.378662109375.
# This is 395th iteration. The loss is 2751.10498046875.
# This is 396th iteration. The loss is 2747.845703125.
# This is 397th iteration. The loss is 2744.601318359375.
# This is 398th iteration. The loss is 2741.37109375.
# This is 399th iteration. The loss is 2738.15625.
# This is 400th iteration. The loss is 2734.954833984375.
# This is 401th iteration. The loss is 2731.768310546875.
# This is 402th iteration. The loss is 2728.595703125.
# This is 403th iteration. The loss is 2725.43701171875.
# This is 404th iteration. The loss is 2722.29248046875.
# This is 405th iteration. The loss is 2719.162841796875.
# This is 406th iteration. The loss is 2716.046142578125.
# This is 407th iteration. The loss is 2712.943603515625.
# This is 408th iteration. The loss is 2709.8544921875.
# This is 409th iteration. The loss is 2706.779541015625.
# This is 410th iteration. The loss is 2703.717529296875.
# This is 411th iteration. The loss is 2700.669189453125.
# This is 412th iteration. The loss is 2697.634765625.
# This is 413th iteration. The loss is 2694.613037109375.
# This is 414th iteration. The loss is 2691.60546875.
# This is 415th iteration. The loss is 2688.60986328125.
# This is 416th iteration. The loss is 2685.628662109375.
# This is 417th iteration. The loss is 2682.65966796875.
# This is 418th iteration. The loss is 2679.7041015625.
# This is 419th iteration. The loss is 2676.760986328125.
# This is 420th iteration. The loss is 2673.8310546875.
# This is 421th iteration. The loss is 2670.913818359375.
# This is 422th iteration. The loss is 2668.009521484375.
# This is 423th iteration. The loss is 2665.1171875.
# This is 424th iteration. The loss is 2662.238037109375.
# This is 425th iteration. The loss is 2659.371337890625.
# This is 426th iteration. The loss is 2656.5166015625.
# This is 427th iteration. The loss is 2653.674072265625.
# This is 428th iteration. The loss is 2650.84423828125.
# This is 429th iteration. The loss is 2648.02685546875.
# This is 430th iteration. The loss is 2645.220947265625.
# This is 431th iteration. The loss is 2642.427734375.
# This is 432th iteration. The loss is 2639.646240234375.
# This is 433th iteration. The loss is 2636.87646484375.
# This is 434th iteration. The loss is 2634.118896484375.
# This is 435th iteration. The loss is 2631.372802734375.
# This is 436th iteration. The loss is 2628.638916015625.
# This is 437th iteration. The loss is 2625.916015625.
# This is 438th iteration. The loss is 2623.204833984375.
# This is 439th iteration. The loss is 2620.505615234375.
# This is 440th iteration. The loss is 2617.8173828125.
# This is 441th iteration. The loss is 2615.140625.
# This is 442th iteration. The loss is 2612.47607421875.
# This is 443th iteration. The loss is 2609.821533203125.
# This is 444th iteration. The loss is 2607.1787109375.
# This is 445th iteration. The loss is 2604.54736328125.
# This is 446th iteration. The loss is 2601.9267578125.
# This is 447th iteration. The loss is 2599.31787109375.
# This is 448th iteration. The loss is 2596.718994140625.
# This is 449th iteration. The loss is 2594.131591796875.
# This is 450th iteration. The loss is 2591.554931640625.
# This is 451th iteration. The loss is 2588.988525390625.
# This is 452th iteration. The loss is 2586.43359375.
# This is 453th iteration. The loss is 2583.88916015625.
# This is 454th iteration. The loss is 2581.355712890625.
# This is 455th iteration. The loss is 2578.83203125.
# This is 456th iteration. The loss is 2576.3193359375.
# This is 457th iteration. The loss is 2573.81689453125.
# This is 458th iteration. The loss is 2571.32470703125.
# This is 459th iteration. The loss is 2568.843505859375.
# This is 460th iteration. The loss is 2566.37158203125.
# This is 461th iteration. The loss is 2563.91064453125.
# This is 462th iteration. The loss is 2561.459716796875.
# This is 463th iteration. The loss is 2559.018798828125.
# This is 464th iteration. The loss is 2556.588134765625.
# This is 465th iteration. The loss is 2554.16748046875.
# This is 466th iteration. The loss is 2551.75634765625.
# This is 467th iteration. The loss is 2549.35546875.
# This is 468th iteration. The loss is 2546.964111328125.
# This is 469th iteration. The loss is 2544.582763671875.
# This is 470th iteration. The loss is 2542.211181640625.
# This is 471th iteration. The loss is 2539.84912109375.
# This is 472th iteration. The loss is 2537.4970703125.
# This is 473th iteration. The loss is 2535.154541015625.
# This is 474th iteration. The loss is 2532.821044921875.
# This is 475th iteration. The loss is 2530.49755859375.
# This is 476th iteration. The loss is 2528.183349609375.
# This is 477th iteration. The loss is 2525.8779296875.
# This is 478th iteration. The loss is 2523.582275390625.
# This is 479th iteration. The loss is 2521.295654296875.
# This is 480th iteration. The loss is 2519.01904296875.
# This is 481th iteration. The loss is 2516.751220703125.
# This is 482th iteration. The loss is 2514.49267578125.
# This is 483th iteration. The loss is 2512.242919921875.
# This is 484th iteration. The loss is 2510.002197265625.
# This is 485th iteration. The loss is 2507.77001953125.
# This is 486th iteration. The loss is 2505.547607421875.
# This is 487th iteration. The loss is 2503.33349609375.
# This is 488th iteration. The loss is 2501.128173828125.
# This is 489th iteration. The loss is 2498.931884765625.
# This is 490th iteration. The loss is 2496.744873046875.
# This is 491th iteration. The loss is 2494.565673828125.
# This is 492th iteration. The loss is 2492.39599609375.
# This is 493th iteration. The loss is 2490.23388671875.
# This is 494th iteration. The loss is 2488.081298828125.
# This is 495th iteration. The loss is 2485.936767578125.
# This is 496th iteration. The loss is 2483.80078125.
# This is 497th iteration. The loss is 2481.673095703125.
# This is 498th iteration. The loss is 2479.553955078125.
# This is 499th iteration. The loss is 2477.443359375.
# This is 500th iteration. The loss is 2475.3408203125.
# This is 501th iteration. The loss is 2473.246826171875.
# This is 502th iteration. The loss is 2471.160888671875.
# This is 503th iteration. The loss is 2469.08251953125.
# This is 504th iteration. The loss is 2467.012939453125.
# This is 505th iteration. The loss is 2464.951416015625.
# This is 506th iteration. The loss is 2462.897705078125.
# This is 507th iteration. The loss is 2460.852294921875.
# This is 508th iteration. The loss is 2458.814697265625.
# This is 509th iteration. The loss is 2456.78466796875.
# This is 510th iteration. The loss is 2454.7626953125.
# This is 511th iteration. The loss is 2452.749267578125.
# This is 512th iteration. The loss is 2450.742919921875.
# This is 513th iteration. The loss is 2448.744384765625.
# This is 514th iteration. The loss is 2446.75341796875.
# This is 515th iteration. The loss is 2444.770263671875.
# This is 516th iteration. The loss is 2442.794921875.
# This is 517th iteration. The loss is 2440.8271484375.
# This is 518th iteration. The loss is 2438.8671875.
# This is 519th iteration. The loss is 2436.91455078125.
# This is 520th iteration. The loss is 2434.968994140625.
# This is 521th iteration. The loss is 2433.03125.
# This is 522th iteration. The loss is 2431.1005859375.
# This is 523th iteration. The loss is 2429.177734375.
# This is 524th iteration. The loss is 2427.26220703125.
# This is 525th iteration. The loss is 2425.353759765625.
# This is 526th iteration. The loss is 2423.45263671875.
# This is 527th iteration. The loss is 2421.559326171875.
# This is 528th iteration. The loss is 2419.672119140625.
# This is 529th iteration. The loss is 2417.79248046875.
# This is 530th iteration. The loss is 2415.92041015625.
# This is 531th iteration. The loss is 2414.054931640625.
# This is 532th iteration. The loss is 2412.19677734375.
# This is 533th iteration. The loss is 2410.34521484375.
# This is 534th iteration. The loss is 2408.500732421875.
# This is 535th iteration. The loss is 2406.66357421875.
# This is 536th iteration. The loss is 2404.832763671875.
# This is 537th iteration. The loss is 2403.009033203125.
# This is 538th iteration. The loss is 2401.192626953125.
# This is 539th iteration. The loss is 2399.383056640625.
# This is 540th iteration. The loss is 2397.579833984375.
# This is 541th iteration. The loss is 2395.782958984375.
# This is 542th iteration. The loss is 2393.993408203125.
# This is 543th iteration. The loss is 2392.210205078125.
# This is 544th iteration. The loss is 2390.43359375.
# This is 545th iteration. The loss is 2388.6640625.
# This is 546th iteration. The loss is 2386.900390625.
# This is 547th iteration. The loss is 2385.143798828125.
# This is 548th iteration. The loss is 2383.3935546875.
# This is 549th iteration. The loss is 2381.649658203125.
# This is 550th iteration. The loss is 2379.912109375.
# This is 551th iteration. The loss is 2378.18115234375.
# This is 552th iteration. The loss is 2376.456298828125.
# This is 553th iteration. The loss is 2374.73828125.
# This is 554th iteration. The loss is 2373.0263671875.
# This is 555th iteration. The loss is 2371.320556640625.
# This is 556th iteration. The loss is 2369.621337890625.
# This is 557th iteration. The loss is 2367.927734375.
# This is 558th iteration. The loss is 2366.240966796875.
# This is 559th iteration. The loss is 2364.560546875.
# This is 560th iteration. The loss is 2362.885498046875.
# This is 561th iteration. The loss is 2361.216552734375.
# This is 562th iteration. The loss is 2359.55419921875.
# This is 563th iteration. The loss is 2357.897705078125.
# This is 564th iteration. The loss is 2356.2470703125.
# This is 565th iteration. The loss is 2354.6025390625.
# This is 566th iteration. The loss is 2352.964111328125.
# This is 567th iteration. The loss is 2351.33154296875.
# This is 568th iteration. The loss is 2349.704345703125.
# This is 569th iteration. The loss is 2348.083740234375.
# This is 570th iteration. The loss is 2346.46875.
# This is 571th iteration. The loss is 2344.859375.
# This is 572th iteration. The loss is 2343.255859375.
# This is 573th iteration. The loss is 2341.657958984375.
# This is 574th iteration. The loss is 2340.06591796875.
# This is 575th iteration. The loss is 2338.479736328125.
# This is 576th iteration. The loss is 2336.899169921875.
# This is 577th iteration. The loss is 2335.323974609375.
# This is 578th iteration. The loss is 2333.75390625.
# This is 579th iteration. The loss is 2332.190673828125.
# This is 580th iteration. The loss is 2330.63232421875.
# This is 581th iteration. The loss is 2329.079833984375.
# This is 582th iteration. The loss is 2327.532470703125.
# This is 583th iteration. The loss is 2325.990966796875.
# This is 584th iteration. The loss is 2324.45458984375.
# This is 585th iteration. The loss is 2322.924072265625.
# This is 586th iteration. The loss is 2321.398193359375.
# This is 587th iteration. The loss is 2319.878173828125.
# This is 588th iteration. The loss is 2318.364013671875.
# This is 589th iteration. The loss is 2316.854248046875.
# This is 590th iteration. The loss is 2315.35009765625.
# This is 591th iteration. The loss is 2313.8515625.
# This is 592th iteration. The loss is 2312.358154296875.
# This is 593th iteration. The loss is 2310.8701171875.
# This is 594th iteration. The loss is 2309.38720703125.
# This is 595th iteration. The loss is 2307.908935546875.
# This is 596th iteration. The loss is 2306.43603515625.
# This is 597th iteration. The loss is 2304.96875.
# This is 598th iteration. The loss is 2303.50634765625.
# This is 599th iteration. The loss is 2302.048583984375.
# This is 600th iteration. The loss is 2300.59619140625.
# This is 601th iteration. The loss is 2299.149169921875.
# This is 602th iteration. The loss is 2297.706787109375.
# This is 603th iteration. The loss is 2296.269287109375.
# This is 604th iteration. The loss is 2294.8369140625.
# This is 605th iteration. The loss is 2293.408935546875.
# This is 606th iteration. The loss is 2291.987060546875.
# This is 607th iteration. The loss is 2290.569091796875.
# This is 608th iteration. The loss is 2289.156494140625.
# This is 609th iteration. The loss is 2287.74853515625.
# This is 610th iteration. The loss is 2286.345703125.
# This is 611th iteration. The loss is 2284.947021484375.
# This is 612th iteration. The loss is 2283.553466796875.
# This is 613th iteration. The loss is 2282.165283203125.
# This is 614th iteration. The loss is 2280.781005859375.
# This is 615th iteration. The loss is 2279.40185546875.
# This is 616th iteration. The loss is 2278.027587890625.
# This is 617th iteration. The loss is 2276.65771484375.
# This is 618th iteration. The loss is 2275.292724609375.
# This is 619th iteration. The loss is 2273.931884765625.
# This is 620th iteration. The loss is 2272.575927734375.
# This is 621th iteration. The loss is 2271.22412109375.
# This is 622th iteration. The loss is 2269.87744140625.
# This is 623th iteration. The loss is 2268.53515625.
# This is 624th iteration. The loss is 2267.197998046875.
# This is 625th iteration. The loss is 2265.86474609375.
# This is 626th iteration. The loss is 2264.535888671875.
# This is 627th iteration. The loss is 2263.2119140625.
# This is 628th iteration. The loss is 2261.891845703125.
# This is 629th iteration. The loss is 2260.576416015625.
# This is 630th iteration. The loss is 2259.265869140625.
# This is 631th iteration. The loss is 2257.958740234375.
# This is 632th iteration. The loss is 2256.656494140625.
# This is 633th iteration. The loss is 2255.35888671875.
# This is 634th iteration. The loss is 2254.065185546875.
# This is 635th iteration. The loss is 2252.775634765625.
# This is 636th iteration. The loss is 2251.49072265625.
# This is 637th iteration. The loss is 2250.2099609375.
# This is 638th iteration. The loss is 2248.933837890625.
# This is 639th iteration. The loss is 2247.66162109375.
# This is 640th iteration. The loss is 2246.3935546875.
# This is 641th iteration. The loss is 2245.1298828125.
# This is 642th iteration. The loss is 2243.869873046875.
# This is 643th iteration. The loss is 2242.614501953125.
# This is 644th iteration. The loss is 2241.36279296875.
# This is 645th iteration. The loss is 2240.11572265625.
# This is 646th iteration. The loss is 2238.87255859375.
# This is 647th iteration. The loss is 2237.633544921875.
# This is 648th iteration. The loss is 2236.39892578125.
# This is 649th iteration. The loss is 2235.16796875.
# This is 650th iteration. The loss is 2233.941162109375.
# This is 651th iteration. The loss is 2232.718017578125.
# This is 652th iteration. The loss is 2231.498779296875.
# This is 653th iteration. The loss is 2230.2841796875.
# This is 654th iteration. The loss is 2229.072998046875.
# This is 655th iteration. The loss is 2227.866455078125.
# This is 656th iteration. The loss is 2226.6630859375.
# This is 657th iteration. The loss is 2225.464111328125.
# This is 658th iteration. The loss is 2224.2685546875.
# This is 659th iteration. The loss is 2223.077392578125.
# This is 660th iteration. The loss is 2221.8896484375.
# This is 661th iteration. The loss is 2220.706298828125.
# This is 662th iteration. The loss is 2219.526123046875.
# This is 663th iteration. The loss is 2218.35009765625.
# This is 664th iteration. The loss is 2217.177490234375.
# This is 665th iteration. The loss is 2216.0087890625.
# This is 666th iteration. The loss is 2214.84375.
# This is 667th iteration. The loss is 2213.68310546875.
# This is 668th iteration. The loss is 2212.525634765625.
# This is 669th iteration. The loss is 2211.3720703125.
# This is 670th iteration. The loss is 2210.22216796875.
# This is 671th iteration. The loss is 2209.075439453125.
# This is 672th iteration. The loss is 2207.932861328125.
# This is 673th iteration. The loss is 2206.7939453125.
# This is 674th iteration. The loss is 2205.65869140625.
# This is 675th iteration. The loss is 2204.527099609375.
# This is 676th iteration. The loss is 2203.3984375.
# This is 677th iteration. The loss is 2202.27392578125.
# This is 678th iteration. The loss is 2201.15283203125.
# This is 679th iteration. The loss is 2200.035400390625.
# This is 680th iteration. The loss is 2198.921630859375.
# This is 681th iteration. The loss is 2197.81103515625.
# This is 682th iteration. The loss is 2196.704345703125.
# This is 683th iteration. The loss is 2195.6005859375.
# This is 684th iteration. The loss is 2194.500732421875.
# This is 685th iteration. The loss is 2193.404052734375.
# This is 686th iteration. The loss is 2192.31103515625.
# This is 687th iteration. The loss is 2191.2216796875.
# This is 688th iteration. The loss is 2190.135498046875.
# This is 689th iteration. The loss is 2189.052490234375.
# This is 690th iteration. The loss is 2187.972900390625.
# This is 691th iteration. The loss is 2186.897216796875.
# This is 692th iteration. The loss is 2185.823974609375.
# This is 693th iteration. The loss is 2184.754638671875.
# This is 694th iteration. The loss is 2183.68896484375.
# This is 695th iteration. The loss is 2182.6259765625.
# This is 696th iteration. The loss is 2181.566650390625.
# This is 697th iteration. The loss is 2180.51025390625.
# This is 698th iteration. The loss is 2179.4580078125.
# This is 699th iteration. The loss is 2178.408203125.
# This is 700th iteration. The loss is 2177.36181640625.
# This is 701th iteration. The loss is 2176.31884765625.
# This is 702th iteration. The loss is 2175.279052734375.
# This is 703th iteration. The loss is 2174.2421875.
# This is 704th iteration. The loss is 2173.208740234375.
# This is 705th iteration. The loss is 2172.17822265625.
# This is 706th iteration. The loss is 2171.15087890625.
# This is 707th iteration. The loss is 2170.12744140625.
# This is 708th iteration. The loss is 2169.10595703125.
# This is 709th iteration. The loss is 2168.088623046875.
# This is 710th iteration. The loss is 2167.073974609375.
# This is 711th iteration. The loss is 2166.0625.
# This is 712th iteration. The loss is 2165.053955078125.
# This is 713th iteration. The loss is 2164.048583984375.
# This is 714th iteration. The loss is 2163.04638671875.
# This is 715th iteration. The loss is 2162.04736328125.
# This is 716th iteration. The loss is 2161.05078125.
# This is 717th iteration. The loss is 2160.0576171875.
# This is 718th iteration. The loss is 2159.0673828125.
# This is 719th iteration. The loss is 2158.080078125.
# This is 720th iteration. The loss is 2157.095947265625.
# This is 721th iteration. The loss is 2156.11474609375.
# This is 722th iteration. The loss is 2155.136474609375.
# This is 723th iteration. The loss is 2154.1611328125.
# This is 724th iteration. The loss is 2153.188720703125.
# This is 725th iteration. The loss is 2152.21923828125.
# This is 726th iteration. The loss is 2151.2529296875.
# This is 727th iteration. The loss is 2150.2890625.
# This is 728th iteration. The loss is 2149.328125.
# This is 729th iteration. The loss is 2148.37060546875.
# This is 730th iteration. The loss is 2147.4150390625.
# This is 731th iteration. The loss is 2146.463134765625.
# This is 732th iteration. The loss is 2145.513671875.
# This is 733th iteration. The loss is 2144.567626953125.
# This is 734th iteration. The loss is 2143.62353515625.
# This is 735th iteration. The loss is 2142.68310546875.
# This is 736th iteration. The loss is 2141.744873046875.
# This is 737th iteration. The loss is 2140.8095703125.
# This is 738th iteration. The loss is 2139.876953125.
# This is 739th iteration. The loss is 2138.947265625.
# This is 740th iteration. The loss is 2138.02001953125.
# This is 741th iteration. The loss is 2137.095703125.
# This is 742th iteration. The loss is 2136.174072265625.
# This is 743th iteration. The loss is 2135.255615234375.
# This is 744th iteration. The loss is 2134.33935546875.
# This is 745th iteration. The loss is 2133.426025390625.
# This is 746th iteration. The loss is 2132.515380859375.
# This is 747th iteration. The loss is 2131.607666015625.
# This is 748th iteration. The loss is 2130.701904296875.
# This is 749th iteration. The loss is 2129.799072265625.
# This is 750th iteration. The loss is 2128.89892578125.
# This is 751th iteration. The loss is 2128.001953125.
# This is 752th iteration. The loss is 2127.10693359375.
# This is 753th iteration. The loss is 2126.21484375.
# This is 754th iteration. The loss is 2125.3251953125.
# This is 755th iteration. The loss is 2124.4384765625.
# This is 756th iteration. The loss is 2123.5537109375.
# This is 757th iteration. The loss is 2122.671875.
# This is 758th iteration. The loss is 2121.79248046875.
# This is 759th iteration. The loss is 2120.91552734375.
# This is 760th iteration. The loss is 2120.04150390625.
# This is 761th iteration. The loss is 2119.169921875.
# This is 762th iteration. The loss is 2118.30029296875.
# This is 763th iteration. The loss is 2117.43359375.
# This is 764th iteration. The loss is 2116.56982421875.
# This is 765th iteration. The loss is 2115.708251953125.
# This is 766th iteration. The loss is 2114.84912109375.
# This is 767th iteration. The loss is 2113.9921875.
# This is 768th iteration. The loss is 2113.1376953125.
# This is 769th iteration. The loss is 2112.2861328125.
# This is 770th iteration. The loss is 2111.4365234375.
# This is 771th iteration. The loss is 2110.58984375.
# This is 772th iteration. The loss is 2109.745361328125.
# This is 773th iteration. The loss is 2108.9033203125.
# This is 774th iteration. The loss is 2108.0634765625.
# This is 775th iteration. The loss is 2107.225830078125.
# This is 776th iteration. The loss is 2106.39111328125.
# This is 777th iteration. The loss is 2105.55859375.
# This is 778th iteration. The loss is 2104.728271484375.
# This is 779th iteration. The loss is 2103.900390625.
# This is 780th iteration. The loss is 2103.075439453125.
# This is 781th iteration. The loss is 2102.251953125.
# This is 782th iteration. The loss is 2101.43115234375.
# This is 783th iteration. The loss is 2100.612548828125.
# This is 784th iteration. The loss is 2099.79638671875.
# This is 785th iteration. The loss is 2098.98291015625.
# This is 786th iteration. The loss is 2098.171142578125.
# This is 787th iteration. The loss is 2097.36181640625.
# This is 788th iteration. The loss is 2096.554931640625.
# This is 789th iteration. The loss is 2095.750244140625.
# This is 790th iteration. The loss is 2094.94775390625.
# This is 791th iteration. The loss is 2094.1474609375.
# This is 792th iteration. The loss is 2093.349365234375.
# This is 793th iteration. The loss is 2092.553466796875.
# This is 794th iteration. The loss is 2091.760009765625.
# This is 795th iteration. The loss is 2090.96875.
# This is 796th iteration. The loss is 2090.179931640625.
# This is 797th iteration. The loss is 2089.39306640625.
# This is 798th iteration. The loss is 2088.60791015625.
# This is 799th iteration. The loss is 2087.82568359375.
# This is 800th iteration. The loss is 2087.04541015625.
# This is 801th iteration. The loss is 2086.267333984375.
# This is 802th iteration. The loss is 2085.4912109375.
# This is 803th iteration. The loss is 2084.717041015625.
# This is 804th iteration. The loss is 2083.94580078125.
# This is 805th iteration. The loss is 2083.17626953125.
# This is 806th iteration. The loss is 2082.408447265625.
# This is 807th iteration. The loss is 2081.64306640625.
# This is 808th iteration. The loss is 2080.879638671875.
# This is 809th iteration. The loss is 2080.11865234375.
# This is 810th iteration. The loss is 2079.35986328125.
# This is 811th iteration. The loss is 2078.6025390625.
# This is 812th iteration. The loss is 2077.847900390625.
# This is 813th iteration. The loss is 2077.09521484375.
# This is 814th iteration. The loss is 2076.34423828125.
# This is 815th iteration. The loss is 2075.59521484375.
# This is 816th iteration. The loss is 2074.8486328125.
# This is 817th iteration. The loss is 2074.104248046875.
# This is 818th iteration. The loss is 2073.361328125.
# This is 819th iteration. The loss is 2072.621337890625.
# This is 820th iteration. The loss is 2071.8828125.
# This is 821th iteration. The loss is 2071.14599609375.
# This is 822th iteration. The loss is 2070.411865234375.
# This is 823th iteration. The loss is 2069.679443359375.
# This is 824th iteration. The loss is 2068.948486328125.
# This is 825th iteration. The loss is 2068.22021484375.
# This is 826th iteration. The loss is 2067.493408203125.
# This is 827th iteration. The loss is 2066.76904296875.
# This is 828th iteration. The loss is 2066.0458984375.
# This is 829th iteration. The loss is 2065.325439453125.
# This is 830th iteration. The loss is 2064.606689453125.
# This is 831th iteration. The loss is 2063.89013671875.
# This is 832th iteration. The loss is 2063.175048828125.
# This is 833th iteration. The loss is 2062.4619140625.
# This is 834th iteration. The loss is 2061.750732421875.
# This is 835th iteration. The loss is 2061.0419921875.
# This is 836th iteration. The loss is 2060.33447265625.
# This is 837th iteration. The loss is 2059.62939453125.
# This is 838th iteration. The loss is 2058.92578125.
# This is 839th iteration. The loss is 2058.224365234375.
# This is 840th iteration. The loss is 2057.52490234375.
# This is 841th iteration. The loss is 2056.826904296875.
# This is 842th iteration. The loss is 2056.130859375.
# This is 843th iteration. The loss is 2055.4365234375.
# This is 844th iteration. The loss is 2054.74462890625.
# This is 845th iteration. The loss is 2054.05419921875.
# This is 846th iteration. The loss is 2053.365478515625.
# This is 847th iteration. The loss is 2052.67822265625.
# This is 848th iteration. The loss is 2051.993896484375.
# This is 849th iteration. The loss is 2051.310546875.
# This is 850th iteration. The loss is 2050.629150390625.
# This is 851th iteration. The loss is 2049.94970703125.
# This is 852th iteration. The loss is 2049.27197265625.
# This is 853th iteration. The loss is 2048.59619140625.
# This is 854th iteration. The loss is 2047.9215087890625.
# This is 855th iteration. The loss is 2047.24951171875.
# This is 856th iteration. The loss is 2046.5784912109375.
# This is 857th iteration. The loss is 2045.9097900390625.
# This is 858th iteration. The loss is 2045.2427978515625.
# This is 859th iteration. The loss is 2044.5775146484375.
# This is 860th iteration. The loss is 2043.9136962890625.
# This is 861th iteration. The loss is 2043.251708984375.
# This is 862th iteration. The loss is 2042.591552734375.
# This is 863th iteration. The loss is 2041.932861328125.
# This is 864th iteration. The loss is 2041.2762451171875.
# This is 865th iteration. The loss is 2040.6214599609375.
# This is 866th iteration. The loss is 2039.968505859375.
# This is 867th iteration. The loss is 2039.316650390625.
# This is 868th iteration. The loss is 2038.66650390625.
# This is 869th iteration. The loss is 2038.0181884765625.
# This is 870th iteration. The loss is 2037.3719482421875.
# This is 871th iteration. The loss is 2036.72705078125.
# This is 872th iteration. The loss is 2036.083984375.
# This is 873th iteration. The loss is 2035.4425048828125.
# This is 874th iteration. The loss is 2034.8028564453125.
# This is 875th iteration. The loss is 2034.164306640625.
# This is 876th iteration. The loss is 2033.52783203125.
# This is 877th iteration. The loss is 2032.8927001953125.
# ...
# This is 1720th iteration. The loss is 1785.3720703125.
# This is 1721th iteration. The loss is 1785.243408203125.
# This is 1722th iteration. The loss is 1785.114990234375.
# This is 1723th iteration. The loss is 1784.987060546875.
# This is 1724th iteration. The loss is 1784.8590087890625.
# This is 1725th iteration. The loss is 1784.7308349609375.
# This is 1726th iteration. The loss is 1784.6033935546875.
# This is 1727th iteration. The loss is 1784.4757080078125.
# This is 1728th iteration. The loss is 1784.3486328125.
# This is 1729th iteration. The loss is 1784.221435546875.
# This is 1730th iteration. The loss is 1784.0941162109375.
# This is 1731th iteration. The loss is 1783.967529296875.
# This is 1732th iteration. The loss is 1783.8408203125.
# This is 1733th iteration. The loss is 1783.71484375.
# This is 1734th iteration. The loss is 1783.5880126953125.
# This is 1735th iteration. The loss is 1783.4620361328125.
# This is 1736th iteration. The loss is 1783.336181640625.
# This is 1737th iteration. The loss is 1783.21044921875.
# This is 1738th iteration. The loss is 1783.0853271484375.
# This is 1739th iteration. The loss is 1782.9595947265625.
# This is 1740th iteration. The loss is 1782.83447265625.
# This is 1741th iteration. The loss is 1782.7093505859375.
# This is 1742th iteration. The loss is 1782.5845947265625.
# This is 1743th iteration. The loss is 1782.4600830078125.
# This is 1744th iteration. The loss is 1782.3355712890625.
# This is 1745th iteration. The loss is 1782.21142578125.
# This is 1746th iteration. The loss is 1782.087158203125.
# This is 1747th iteration. The loss is 1781.9635009765625.
# This is 1748th iteration. The loss is 1781.839111328125.
# This is 1749th iteration. The loss is 1781.7159423828125.
# This is 1750th iteration. The loss is 1781.592529296875.
# This is 1751th iteration. The loss is 1781.4691162109375.
# This is 1752th iteration. The loss is 1781.3458251953125.
# This is 1753th iteration. The loss is 1781.223388671875.
# This is 1754th iteration. The loss is 1781.1004638671875.
# This is 1755th iteration. The loss is 1780.9779052734375.
# This is 1756th iteration. The loss is 1780.85595703125.
# This is 1757th iteration. The loss is 1780.7335205078125.
# This is 1758th iteration. The loss is 1780.6114501953125.
# This is 1759th iteration. The loss is 1780.4892578125.
# This is 1760th iteration. The loss is 1780.36767578125.
# This is 1761th iteration. The loss is 1780.24609375.
# This is 1762th iteration. The loss is 1780.1248779296875.
# This is 1763th iteration. The loss is 1780.003662109375.
# This is 1764th iteration. The loss is 1779.883056640625.
# This is 1765th iteration. The loss is 1779.761962890625.
# This is 1766th iteration. The loss is 1779.641357421875.
# This is 1767th iteration. The loss is 1779.5206298828125.
# This is 1768th iteration. The loss is 1779.400634765625.
# This is 1769th iteration. The loss is 1779.2801513671875.
# This is 1770th iteration. The loss is 1779.1600341796875.
# This is 1771th iteration. The loss is 1779.04052734375.
# This is 1772th iteration. The loss is 1778.921142578125.
# This is 1773th iteration. The loss is 1778.801025390625.
# This is 1774th iteration. The loss is 1778.6820068359375.
# This is 1775th iteration. The loss is 1778.5628662109375.
# This is 1776th iteration. The loss is 1778.44384765625.
# This is 1777th iteration. The loss is 1778.3248291015625.
# This is 1778th iteration. The loss is 1778.2061767578125.
# This is 1779th iteration. The loss is 1778.08740234375.
# This is 1780th iteration. The loss is 1777.9691162109375.
# This is 1781th iteration. The loss is 1777.8511962890625.
# This is 1782th iteration. The loss is 1777.733154296875.
# This is 1783th iteration. The loss is 1777.6153564453125.
# This is 1784th iteration. The loss is 1777.497802734375.
# This is 1785th iteration. The loss is 1777.3798828125.
# This is 1786th iteration. The loss is 1777.262451171875.
# This is 1787th iteration. The loss is 1777.1456298828125.
# This is 1788th iteration. The loss is 1777.0284423828125.
# This is 1789th iteration. The loss is 1776.91162109375.
# This is 1790th iteration. The loss is 1776.794921875.
# This is 1791th iteration. The loss is 1776.6783447265625.
# This is 1792th iteration. The loss is 1776.5621337890625.
# This is 1793th iteration. The loss is 1776.446044921875.
# This is 1794th iteration. The loss is 1776.3294677734375.
# This is 1795th iteration. The loss is 1776.2138671875.
# This is 1796th iteration. The loss is 1776.0982666015625.
# This is 1797th iteration. The loss is 1775.9825439453125.
# This is 1798th iteration. The loss is 1775.8668212890625.
# This is 1799th iteration. The loss is 1775.7520751953125.
# This is 1800th iteration. The loss is 1775.636474609375.
# This is 1801th iteration. The loss is 1775.5216064453125.
# This is 1802th iteration. The loss is 1775.40673828125.
# This is 1803th iteration. The loss is 1775.2923583984375.
# This is 1804th iteration. The loss is 1775.177978515625.
# This is 1805th iteration. The loss is 1775.063720703125.
# This is 1806th iteration. The loss is 1774.94921875.
# This is 1807th iteration. The loss is 1774.83544921875.
# This is 1808th iteration. The loss is 1774.72119140625.
# This is 1809th iteration. The loss is 1774.607666015625.
# This is 1810th iteration. The loss is 1774.4942626953125.
# This is 1811th iteration. The loss is 1774.3812255859375.
# This is 1812th iteration. The loss is 1774.267578125.
# This is 1813th iteration. The loss is 1774.154541015625.
# This is 1814th iteration. The loss is 1774.041748046875.
# This is 1815th iteration. The loss is 1773.9287109375.
# This is 1816th iteration. The loss is 1773.8165283203125.
# This is 1817th iteration. The loss is 1773.703857421875.
# This is 1818th iteration. The loss is 1773.5914306640625.
# This is 1819th iteration. The loss is 1773.479248046875.
# This is 1820th iteration. The loss is 1773.367431640625.
# This is 1821th iteration. The loss is 1773.2554931640625.
# This is 1822th iteration. The loss is 1773.143798828125.
# This is 1823th iteration. The loss is 1773.0323486328125.
# This is 1824th iteration. The loss is 1772.9208984375.
# This is 1825th iteration. The loss is 1772.8094482421875.
# This is 1826th iteration. The loss is 1772.698486328125.
# This is 1827th iteration. The loss is 1772.5877685546875.
# This is 1828th iteration. The loss is 1772.47705078125.
# This is 1829th iteration. The loss is 1772.366455078125.
# This is 1830th iteration. The loss is 1772.255859375.
# This is 1831th iteration. The loss is 1772.145263671875.
# This is 1832th iteration. The loss is 1772.03515625.
# This is 1833th iteration. The loss is 1771.9251708984375.
# This is 1834th iteration. The loss is 1771.8153076171875.
# This is 1835th iteration. The loss is 1771.7056884765625.
# This is 1836th iteration. The loss is 1771.595947265625.
# This is 1837th iteration. The loss is 1771.486328125.
# This is 1838th iteration. The loss is 1771.3773193359375.
# This is 1839th iteration. The loss is 1771.267578125.
# This is 1840th iteration. The loss is 1771.158935546875.
# This is 1841th iteration. The loss is 1771.0499267578125.
# This is 1842th iteration. The loss is 1770.9415283203125.
# This is 1843th iteration. The loss is 1770.8330078125.
# This is 1844th iteration. The loss is 1770.7242431640625.
# This is 1845th iteration. The loss is 1770.6163330078125.
# This is 1846th iteration. The loss is 1770.50830078125.
# This is 1847th iteration. The loss is 1770.4002685546875.
# This is 1848th iteration. The loss is 1770.2923583984375.
# This is 1849th iteration. The loss is 1770.1846923828125.
# This is 1850th iteration. The loss is 1770.0770263671875.
# This is 1851th iteration. The loss is 1769.9698486328125.
# This is 1852th iteration. The loss is 1769.8621826171875.
# This is 1853th iteration. The loss is 1769.755615234375.
# This is 1854th iteration. The loss is 1769.6484375.
# This is 1855th iteration. The loss is 1769.541259765625.
# This is 1856th iteration. The loss is 1769.434814453125.
# This is 1857th iteration. The loss is 1769.3282470703125.
# This is 1858th iteration. The loss is 1769.221923828125.
# This is 1859th iteration. The loss is 1769.1156005859375.
# This is 1860th iteration. The loss is 1769.0096435546875.
# This is 1861th iteration. The loss is 1768.9031982421875.
# This is 1862th iteration. The loss is 1768.7978515625.
# This is 1863th iteration. The loss is 1768.692138671875.
# This is 1864th iteration. The loss is 1768.58642578125.
# This is 1865th iteration. The loss is 1768.4810791015625.
# This is 1866th iteration. The loss is 1768.3760986328125.
# This is 1867th iteration. The loss is 1768.2705078125.
# This is 1868th iteration. The loss is 1768.16552734375.
# This is 1869th iteration. The loss is 1768.060546875.
# This is 1870th iteration. The loss is 1767.9560546875.
# This is 1871th iteration. The loss is 1767.8514404296875.
# This is 1872th iteration. The loss is 1767.7471923828125.
# This is 1873th iteration. The loss is 1767.64306640625.
# This is 1874th iteration. The loss is 1767.5386962890625.
# This is 1875th iteration. The loss is 1767.4344482421875.
# This is 1876th iteration. The loss is 1767.3309326171875.
# This is 1877th iteration. The loss is 1767.2271728515625.
# This is 1878th iteration. The loss is 1767.123291015625.
# This is 1879th iteration. The loss is 1767.0198974609375.
# This is 1880th iteration. The loss is 1766.9166259765625.
# This is 1881th iteration. The loss is 1766.8135986328125.
# This is 1882th iteration. The loss is 1766.7103271484375.
# This is 1883th iteration. The loss is 1766.607421875.
# This is 1884th iteration. The loss is 1766.5047607421875.
# This is 1885th iteration. The loss is 1766.402099609375.
# This is 1886th iteration. The loss is 1766.299560546875.
# This is 1887th iteration. The loss is 1766.19677734375.
# This is 1888th iteration. The loss is 1766.094970703125.
# This is 1889th iteration. The loss is 1765.9927978515625.
# This is 1890th iteration. The loss is 1765.8907470703125.
# This is 1891th iteration. The loss is 1765.788818359375.
# This is 1892th iteration. The loss is 1765.6873779296875.
# This is 1893th iteration. The loss is 1765.58544921875.
# This is 1894th iteration. The loss is 1765.4842529296875.
# This is 1895th iteration. The loss is 1765.3829345703125.
# This is 1896th iteration. The loss is 1765.28173828125.
# This is 1897th iteration. The loss is 1765.1805419921875.
# This is 1898th iteration. The loss is 1765.0802001953125.
# This is 1899th iteration. The loss is 1764.978759765625.
# This is 1900th iteration. The loss is 1764.87841796875.
# This is 1901th iteration. The loss is 1764.7781982421875.
# This is 1902th iteration. The loss is 1764.677734375.
# This is 1903th iteration. The loss is 1764.577392578125.
# This is 1904th iteration. The loss is 1764.4769287109375.
# This is 1905th iteration. The loss is 1764.3775634765625.
# This is 1906th iteration. The loss is 1764.277099609375.
# This is 1907th iteration. The loss is 1764.1773681640625.
# This is 1908th iteration. The loss is 1764.0782470703125.
# This is 1909th iteration. The loss is 1763.9786376953125.
# This is 1910th iteration. The loss is 1763.8790283203125.
# This is 1911th iteration. The loss is 1763.7802734375.
# This is 1912th iteration. The loss is 1763.680908203125.
# This is 1913th iteration. The loss is 1763.58203125.
# This is 1914th iteration. The loss is 1763.4833984375.
# This is 1915th iteration. The loss is 1763.384765625.
# This is 1916th iteration. The loss is 1763.2860107421875.
# This is 1917th iteration. The loss is 1763.187255859375.
# This is 1918th iteration. The loss is 1763.089599609375.
# This is 1919th iteration. The loss is 1762.9908447265625.
# This is 1920th iteration. The loss is 1762.89306640625.
# This is 1921th iteration. The loss is 1762.795166015625.
# This is 1922th iteration. The loss is 1762.6973876953125.
# This is 1923th iteration. The loss is 1762.599609375.
# This is 1924th iteration. The loss is 1762.5023193359375.
# This is 1925th iteration. The loss is 1762.40478515625.
# This is 1926th iteration. The loss is 1762.3077392578125.
# This is 1927th iteration. The loss is 1762.2108154296875.
# This is 1928th iteration. The loss is 1762.1131591796875.
# This is 1929th iteration. The loss is 1762.0167236328125.
# This is 1930th iteration. The loss is 1761.9197998046875.
# This is 1931th iteration. The loss is 1761.8232421875.
# This is 1932th iteration. The loss is 1761.7266845703125.
# This is 1933th iteration. The loss is 1761.630615234375.
# This is 1934th iteration. The loss is 1761.533935546875.
# This is 1935th iteration. The loss is 1761.437744140625.
# This is 1936th iteration. The loss is 1761.3416748046875.
# This is 1937th iteration. The loss is 1761.2459716796875.
# This is 1938th iteration. The loss is 1761.1497802734375.
# This is 1939th iteration. The loss is 1761.0545654296875.
# This is 1940th iteration. The loss is 1760.958740234375.
# This is 1941th iteration. The loss is 1760.8634033203125.
# This is 1942th iteration. The loss is 1760.768310546875.
# This is 1943th iteration. The loss is 1760.67333984375.
# This is 1944th iteration. The loss is 1760.577880859375.
# This is 1945th iteration. The loss is 1760.48291015625.
# This is 1946th iteration. The loss is 1760.38818359375.
# This is 1947th iteration. The loss is 1760.293701171875.
# This is 1948th iteration. The loss is 1760.198974609375.
# This is 1949th iteration. The loss is 1760.1044921875.
# This is 1950th iteration. The loss is 1760.010498046875.
# This is 1951th iteration. The loss is 1759.916015625.
# This is 1952th iteration. The loss is 1759.8218994140625.
# This is 1953th iteration. The loss is 1759.7279052734375.
# This is 1954th iteration. The loss is 1759.6343994140625.
# This is 1955th iteration. The loss is 1759.54052734375.
# This is 1956th iteration. The loss is 1759.447265625.
# This is 1957th iteration. The loss is 1759.353271484375.
# This is 1958th iteration. The loss is 1759.2598876953125.
# This is 1959th iteration. The loss is 1759.1671142578125.
# This is 1960th iteration. The loss is 1759.0736083984375.
# This is 1961th iteration. The loss is 1758.980712890625.
# This is 1962th iteration. The loss is 1758.8880615234375.
# This is 1963th iteration. The loss is 1758.7952880859375.
# This is 1964th iteration. The loss is 1758.70263671875.
# This is 1965th iteration. The loss is 1758.60986328125.
# This is 1966th iteration. The loss is 1758.5179443359375.
# This is 1967th iteration. The loss is 1758.4251708984375.
# This is 1968th iteration. The loss is 1758.3331298828125.
# This is 1969th iteration. The loss is 1758.2413330078125.
# This is 1970th iteration. The loss is 1758.1492919921875.
# This is 1971th iteration. The loss is 1758.0574951171875.
# This is 1972th iteration. The loss is 1757.9654541015625.
# This is 1973th iteration. The loss is 1757.8740234375.
# This is 1974th iteration. The loss is 1757.782470703125.
# This is 1975th iteration. The loss is 1757.6912841796875.
# This is 1976th iteration. The loss is 1757.5999755859375.
# This is 1977th iteration. The loss is 1757.5089111328125.
# This is 1978th iteration. The loss is 1757.417724609375.
# This is 1979th iteration. The loss is 1757.3271484375.
# This is 1980th iteration. The loss is 1757.2359619140625.
# This is 1981th iteration. The loss is 1757.1455078125.
# This is 1982th iteration. The loss is 1757.0546875.
# This is 1983th iteration. The loss is 1756.9644775390625.
# This is 1984th iteration. The loss is 1756.8743896484375.
# This is 1985th iteration. The loss is 1756.783935546875.
# This is 1986th iteration. The loss is 1756.6939697265625.
# This is 1987th iteration. The loss is 1756.603515625.
# This is 1988th iteration. The loss is 1756.5142822265625.
# This is 1989th iteration. The loss is 1756.4239501953125.
# This is 1990th iteration. The loss is 1756.3345947265625.
# This is 1991th iteration. The loss is 1756.2451171875.
# This is 1992th iteration. The loss is 1756.15576171875.
# This is 1993th iteration. The loss is 1756.0665283203125.
# This is 1994th iteration. The loss is 1755.97705078125.
# This is 1995th iteration. The loss is 1755.8880615234375.
# This is 1996th iteration. The loss is 1755.7991943359375.
# This is 1997th iteration. The loss is 1755.710205078125.
# This is 1998th iteration. The loss is 1755.6212158203125.
# This is 1999th iteration. The loss is 1755.53271484375.
# test accuracy 0.14

# %%
test_im = mnist.test.images @ W.T @ W
print("test accuracy %g" % accuracy.eval(feed_dict = {x: test_im, y_: mnist.test.labels, keep_prob: 0.8}, session = sess))
# Out:
# test accuracy 0.099
